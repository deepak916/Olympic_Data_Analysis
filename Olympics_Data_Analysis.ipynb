# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
athelets = pd.read_csv('/content/drive/MyDrive/Olympic Kaggle dataset/athlete_events.csv')
regions = pd.read_csv('/content/drive/MyDrive/Olympic Kaggle dataset/noc_regions.csv')

# %%
regions.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
athelets.tail()
# Out:
#             ID  ... Medal
# 271111  135569  ...   NaN
# 271112  135570  ...   NaN
# 271113  135570  ...   NaN
# 271114  135571  ...   NaN
# 271115  135571  ...   NaN
#
# [5 rows x 15 columns]

# %%
# merge dataframe

df_atheletes = athelets.merge(regions, how = 'left', on = 'NOC')  # on parameter is for common column
df_atheletes.head()
# Out:
#    ID                      Name Sex  ...  Medal       region  notes
# 0   1                 A Dijiang   M  ...    NaN        China    NaN
# 1   2                  A Lamusi   M  ...    NaN        China    NaN
# 2   3       Gunnar Nielsen Aaby   M  ...    NaN      Denmark    NaN
# 3   4      Edgar Lindenau Aabye   M  ...   Gold      Denmark    NaN
# 4   5  Christine Jacoba Aaftink   F  ...    NaN  Netherlands    NaN
#
# [5 rows x 17 columns]

# %%
df_atheletes.shape
# Out:
# (271116, 17)

# %%
# making column name consistant

df_atheletes.rename(columns = {'region' : 'Region', 'notes': 'Notes'}, inplace =True);
df_atheletes.head()
# Out:
#    ID                      Name Sex  ...  Medal       Region  Notes
# 0   1                 A Dijiang   M  ...    NaN        China    NaN
# 1   2                  A Lamusi   M  ...    NaN        China    NaN
# 2   3       Gunnar Nielsen Aaby   M  ...    NaN      Denmark    NaN
# 3   4      Edgar Lindenau Aabye   M  ...   Gold      Denmark    NaN
# 4   5  Christine Jacoba Aaftink   F  ...    NaN  Netherlands    NaN
#
# [5 rows x 17 columns]

# %%
# information of data

df_atheletes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 271116 entries, 0 to 271115
# Data columns (total 17 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
#  15  Region  270746 non-null  object
#  16  Notes   5039 non-null    object
# dtypes: float64(3), int64(2), object(12)
# memory usage: 37.2+ MB

# %%
# describe 

df_atheletes.describe()
# Out:
#                   ID            Age  ...         Weight           Year
# count  271116.000000  261642.000000  ...  208241.000000  271116.000000
# mean    68248.954396      25.556898  ...      70.702393    1978.378480
# std     39022.286345       6.393561  ...      14.348020      29.877632
# min         1.000000      10.000000  ...      25.000000    1896.000000
# 25%     34643.000000      21.000000  ...      60.000000    1960.000000
# 50%     68205.000000      24.000000  ...      70.000000    1988.000000
# 75%    102097.250000      28.000000  ...      79.000000    2002.000000
# max    135571.000000      97.000000  ...     214.000000    2016.000000
#
# [8 rows x 5 columns]

# %%
# checking nulll values

nan_values = df_atheletes.isna()
nan_columns = nan_values.any()
nan_columns
# Out:
# ID        False
# Name      False
# Sex       False
# Age        True
# Height     True
# Weight     True
# Team      False
# NOC       False
# Games     False
# Year      False
# Season    False
# City      False
# Sport     False
# Event     False
# Medal      True
# Region     True
# Notes      True
# dtype: bool

# %%
# total nan values

df_atheletes.isnull().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# Region       370
# Notes     266077
# dtype: int64

# %%
# null columns in form of list

athelets_list = df_atheletes.columns[df_atheletes.isnull().any()].tolist()
athelets_list
# Out:
# ['Age', 'Height', 'Weight', 'Medal', 'Region', 'Notes']

# %% [markdown]
# # India Details in Olympics

# %%
# by using function query

df_ind_atheletes = df_atheletes.query('Team == "India" ')
df_ind_atheletes
# Out:
#             ID                                           Name  ... Region  Notes
# 505        281                                 S. Abdul Hamid  ...  India    NaN
# 506        281                                 S. Abdul Hamid  ...  India    NaN
# 895        512                Shiny Kurisingal Abraham-Wilson  ...  India    NaN
# 896        512                Shiny Kurisingal Abraham-Wilson  ...  India    NaN
# 897        512                Shiny Kurisingal Abraham-Wilson  ...  India    NaN
# ...        ...                                            ...  ...    ...    ...
# 264139  132177                           Mohammad Anas Yahiya  ...  India    NaN
# 265876  133029  Thyadathuvilla Chandrapillai "T. C." Yohannan  ...  India    NaN
# 266934  133554                           Sayed Muhammad Yusuf  ...  India    NaN
# 270912  135480                                   Geeta Zutshi  ...  India    NaN
# 270913  135480                                   Geeta Zutshi  ...  India    NaN
#
# ...

# %%
len(df_ind_atheletes) # Total atheletes from INDIA
# Out:
# 1400

# %%
# India Gold Medals since 1896

df_ind_gold = df_ind_atheletes.query('Medal == "Gold" ')
len(df_ind_gold)
# Out:
# 138

# %%
df_gold_2021 = df_ind_gold.query('Year == "1928" ')
df_gold_2021
# Out:
#             ID                                   Name Sex  ...  Medal  Region  Notes
# 4732      2699                            Shaukat Ali   M  ...   Gold   India    NaN
# 5032      2864                    Richard James Allen   M  ...   Gold   India    NaN
# 38352    19716                       Dhyan Chand Bais   M  ...   Gold   India    NaN
# 76886    39020                Michael Anthony Gateley   M  ...   Gold   India    NaN
# 82144    41710  William James "Willie" Goodsir-Cullen   M  ...   Gold   India    NaN
# 89524    45360                 Leslie Charles Hammond   M  ...   Gold   India    NaN
# 116859   59150             Feroz-ud-Din "Feroze" Khan   M  ...   Gold   India    NaN
# 150463   75490          George Eric McCarthy Marthins   M  ...   Gold   India    NaN
# 173081   86987         Richard Alexander "Rex" Norris   M  ...   Gold   India    NaN
# 189138   95008                   Broome Eric Pinniger   M  ...   Gold   India    NaN
# ...

# %%
# Top countries participating since 1896

top10_country = df_atheletes.Team.value_counts().sort_values(ascending=False).head(10)
top10_country
# Out:
# United States    17847
# France           11988
# Great Britain    11404
# Italy            10260
# Germany           9326
# Canada            9279
# Japan             8289
# Sweden            8052
# Australia         7513
# Hungary           6547
# Name: Team, dtype: int64

# %%
# plot for the top 10 country

plt.figure(figsize=(12,6))
plt.xticks(rotation=30)
plt.title("Top 10 Countries")
sns.barplot(x=top10_country.index, y=top10_country, palette='Set2')

# %%
# Age distribution

plt.figure(figsize=(12,6))
plt.title('Age distribution of Atheletes')
plt.xlabel('Age')
plt.ylabel('No: of Participants')
plt.hist(df_atheletes.Age, bins = np.arange(10,80,2), color='orange', edgecolor = 'white')
plt.show()

# %%
winter_sports = df_atheletes[df_atheletes.Season== 'Winter'].Sport.unique()
winter_sports
# Out:
# array(['Speed Skating', 'Cross Country Skiing', 'Ice Hockey', 'Biathlon',
#        'Alpine Skiing', 'Luge', 'Bobsleigh', 'Figure Skating',
#        'Nordic Combined', 'Freestyle Skiing', 'Ski Jumping', 'Curling',
#        'Snowboarding', 'Short Track Speed Skating', 'Skeleton',
#        'Military Ski Patrol', 'Alpinism'], dtype=object)

# %%
summer_sports = df_atheletes[df_atheletes.Season== 'Summer'].Sport.unique()
summer_sports
# Out:
# array(['Basketball', 'Judo', 'Football', 'Tug-Of-War', 'Athletics',
#        'Swimming', 'Badminton', 'Sailing', 'Gymnastics',
#        'Art Competitions', 'Handball', 'Weightlifting', 'Wrestling',
#        'Water Polo', 'Hockey', 'Rowing', 'Fencing', 'Equestrianism',
#        'Shooting', 'Boxing', 'Taekwondo', 'Cycling', 'Diving', 'Canoeing',
#        'Tennis', 'Modern Pentathlon', 'Golf', 'Softball', 'Archery',
#        'Volleyball', 'Synchronized Swimming', 'Table Tennis', 'Baseball',
#        'Rhythmic Gymnastics', 'Rugby Sevens', 'Trampolining',
#        'Beach Volleyball', 'Triathlon', 'Rugby', 'Lacrosse', 'Polo',
#        'Cricket', 'Ice Hockey', 'Racquets', 'Motorboating', 'Croquet',
#        'Figure Skating', 'Jeu De Paume', 'Roque', 'Basque Pelota',
#        'Alpinism', 'Aeronautics'], dtype=object)

# %%
# male and female total participant

gender_counts = df_atheletes.Sex.value_counts()
gender_counts
# Out:
# M    196594
# F     74522
# Name: Sex, dtype: int64

# %%
# Pie plot for male and female distribution 
plt.figure(figsize=(12,6))
plt.title('Pie Plot Male & Female participant')
plt.pie(gender_counts, labels = gender_counts.index, autopct='%1.1f%%', startangle=10, shadow=True)
plt.show()

# %%
# Total medals

df_atheletes.Medal.value_counts()
# Out:
# Gold      13372
# Bronze    13295
# Silver    13116
# Name: Medal, dtype: int64

# %%
# Total medals for india

df_ind_atheletes.Medal.value_counts()
# Out:
# Gold      138
# Bronze     40
# Silver     19
# Name: Medal, dtype: int64

# %%
# Total number of fe,ale atheletes since 1896

#df_atheletes.Sex.value_counts('female')

female_participant = df_atheletes[(df_atheletes.Sex=='F') & (df_atheletes.Season=='Summer')][['Sex', 'Year']]
female_participant = female_participant.groupby('Year').count().reset_index()
female_participant
# Out:
#     Year   Sex
# 0   1900    33
# 1   1904    16
# 2   1906    11
# 3   1908    47
# 4   1912    87
# 5   1920   134
# 6   1924   244
# 7   1928   404
# 8   1932   347
# 9   1936   468
# 10  1948   628
# 11  1952  1497
# 12  1956   893
# 13  1960  1435
# 14  1964  1348
# 15  1968  1777
# 16  1972  2193
# 17  1976  2172
# 18  1980  1756
# 19  1984  2447
# 20  1988  3543
# 21  1992  4124
# 22  1996  5008
# 23  2000  5431
# 24  2004  5546
# 25  2008  5816
# 26  2012  5815
# 27  2016  6223

# %%
womenOlympics = df_atheletes[(df_atheletes.Sex=='F') & (df_atheletes.Season == 'Summer')]

# %%
sns.set(style = 'darkgrid')
plt.figure(figsize=(20,10))
sns.countplot(x = 'Year', data=womenOlympics, palette= 'Spectral')
plt.title('Women Participation')
plt.show()

# %%
part = womenOlympics.groupby('Year')['Sex'].value_counts()
plt.figure(figsize=(20,10))
part.loc[:, 'F'].plot()
plt.title('Plot of Female Atheletes overtime')
plt.show()

# %%
# Gold medal atheletes

goldmedal = df_atheletes[(df_atheletes.Medal == 'Gold')]
goldmedal.head()
# Out:
#     ID                     Name Sex  ...  Medal   Region  Notes
# 3    4     Edgar Lindenau Aabye   M  ...   Gold  Denmark    NaN
# 42  17  Paavo Johannes Aaltonen   M  ...   Gold  Finland    NaN
# 44  17  Paavo Johannes Aaltonen   M  ...   Gold  Finland    NaN
# 48  17  Paavo Johannes Aaltonen   M  ...   Gold  Finland    NaN
# 60  20       Kjetil Andr Aamodt   M  ...   Gold   Norway    NaN
#
# [5 rows x 17 columns]

# %%
# Take only the vallues which are dfferernt from the nan

goldmedal = goldmedal[np.isfinite(goldmedal['Age'])]

# %%
# Gold secure beyond the age of 60 years

goldmedal['ID'][goldmedal['Age']>60].count()
# Out:
# 6

# %%
# from which sports these 6 gold medal has come

sporting_medal = goldmedal['Sport'][goldmedal['Age']>60]
sporting_medal
# Out:
# 104003    Art Competitions
# 105199               Roque
# 190952             Archery
# 226374             Archery
# 233390            Shooting
# 261102             Archery
# Name: Sport, dtype: object

# %%
#plot sports

plt.figure(figsize=(20,10))
plt.tight_layout()
sns.countplot(sporting_medal)
plt.title('Gold Medals for Atheletes over 60yrs of age')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# gold medals from each country

goldmedal.Region.value_counts().reset_index(name='Medal').head()
# Out:
#      index  Medal
# 0      USA   2627
# 1   Russia   1599
# 2  Germany   1293
# 3       UK    657
# 4    Italy    567

# %%
totalgoldmedal = goldmedal.Region.value_counts().reset_index(name='Medal').head(10)
g = sns.catplot(x='index', y = 'Medal', data=totalgoldmedal, height=5, kind='bar', palette='rocket')

g.despine(left=True)
g.set_xlabels('Top 10 countries')
g.set_ylabels('No: of medals')
plt.title('Gold Medal per Country')
plt.xticks(rotation=40)
plt.show()

# %%
# Rio Olympics

max_year = df_atheletes.Year.max()
print(max_year, 'Rio Olympics')

team_names = df_atheletes[(df_atheletes.Year==max_year) & (df_atheletes.Medal=='Gold') ].Team

team_names.value_counts().head(10)
# Out:
# 2016 Rio Olympics
# United States    137
# Great Britain     64
# Russia            50
# Germany           47
# China             44
# Brazil            34
# Australia         23
# Argentina         21
# France            20
# Japan             17
# Name: Team, dtype: int64

# %%
sns.barplot(x=team_names.value_counts().head(20), y=team_names.value_counts().head(20).index)

plt.ylabel(None);
plt.xlabel('Country wise medal for the year 2016')
plt.show()

# %%
# Atheletes who have won a medal 

not_null_medal = df_atheletes[(df_atheletes['Height'].notnull()) & (df_atheletes['Weight'].notnull())]

# %%
plt.figure(figsize=(12, 10))
axis = sns.scatterplot(x='Height', y = 'Weight', data=not_null_medal, hue='Sex')
plt.title('Height vs Weight')
plt.show()

# %% [markdown]
# ***Thank You***
